# %% [markdown]
# # Create Dashboard

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv('../data/trees.csv')
base.head(5)
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
base.describe()
# Out:
#            Girth     Height     Volume
# count  31.000000  31.000000  31.000000
# mean   13.248387  76.000000  30.170968
# std     3.138139   6.371813  16.437846
# min     8.300000  63.000000  10.200000
# 25%    11.050000  72.000000  19.400000
# 50%    12.900000  76.000000  24.200000
# 75%    15.250000  80.000000  37.300000
# max    20.600000  87.000000  77.000000

# %%
base.corr()
# Out:
#            Girth   Height    Volume
# Girth   1.000000  0.51928  0.967119
# Height  0.519280  1.00000  0.598250
# Volume  0.967119  0.59825  1.000000

# %%
sns.distplot(base.iloc[:,1],hist = True)
# Out:
# C:\Users\mrsys\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\mrsys\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.scatter(base.Girth, base.Volume)
plt.title('Trees')
plt.ylabel('Volume')
plt.xlabel('Circ')
# Out:
# Text(0.5,0,'Circ')

# %%
sns.regplot(base.Girth, base.Volume, data=base, x_jitter = 0.2)
# Out:
# C:\Users\mrsys\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume)

plt.figure(1)
plt.subplot(2,2,2)
plt.scatter(base.Height, base.Volume)

plt.figure(1)
plt.subplot(2,2,3)
plt.scatter(base.Girth, base.Height)

plt.figure(1)
plt.subplot(2,2,4)
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(base.Volume)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f384d7c50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f384e34e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f384d7a58>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f384e3da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f384ea240>],
#  'means': []}

# %%
sns.boxplot(base.Volume).set_title('Trees')
# Out:
# Text(0.5,1,'Trees')

# %%
sns.boxplot(data = base)

# %%
sns.distplot(base.Volume, bins = 10, axlabel='Volume').set_title('Trees')
# Out:
# C:\Users\mrsys\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\mrsys\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,'Trees')

# %%
base2 = pd.read_csv('../data/chicken.csv')
grouped = base2.groupby(['feed'])['weight'].sum()

# %%
test =
